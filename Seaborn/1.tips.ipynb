# %%
import seaborn as sns

# %%
df=sns.load_dataset('tips') # preloaded datset of seaborn so only give name of that dataset
                             #itanic,iris,penquin,diamonds
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Target columns--tips

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.shape
# Out:
# (244, 7)

# %%
df.dtypes #already preloaded data ,so give datatype as category same as object
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# FEATURE SELECTION
# TWO METHODS  ==corelation,chisquare test
# Corelation ==find relation between target column and others,it shows how one column is related to other column(numerical clm)
# 1.positive corelation ==if value of one column increases value of other column increases(max range +1)
# 2.negative co relation=one value increases other decreases max value (max range -1 )
# 3.no coreltion ==No relationship between variables
# RANGE == FROM +1 TO -1

# %%
#numeric_only -take only numeric values ,get corelation metrics 
correlation=df.corr(numeric_only=True)
correlation  #comparison of columns ,
             #correltion usd for numerical value*TOTALBILL,TIP,SIZE),for categorical data use chisqure test
             #Diagonal elements should be one 
            
             #The output is called coreltion metrics
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#Heat mat==function in seaborn ,used to visualise corelation
#corelation matric is positive so heat map also has positive value
#light color==strong corelation (tip,totalbill,size)
#black color=dark color(tip-size ,size-tip )

sns.heatmap(correlation)
# Out:
# <Axes: >

# %%
#to change color tone use cmap
sns.heatmap(correlation,cmap='coolwarm')
# Out:
# <Axes: >

# %%
#2) JOINTPLOT
#numerical variables relation
#histogram right=data corre to tips
#histogram top=data corre to total biill
#y-target columns,x values can change
sns.jointplot(x='total_bill',y='tip',data=df)

# %%
sns.jointplot(x='size',y='tip',data=df)

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='hex')#hex=hexagon shape kind=reg (to form regression line to find the desribution type)
#dark color==more distribution(get more tip and bill)

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='reg')

# %%
#PAIR PLOT ==visual represwntation ,Numerical variables relation(multiple)
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')  #bill more spent-male,more tip give-male,more portion size take -male

# %%
#count plot
#only give name of column and data 
#only for categorical column 
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='smoker',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='day',data=df,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x='smoker',data=df,hue='sex')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
#5,BAR PLOT ( comparison between numericl and categorical data)
#line(black) in diagram called ==error  bar ,if length of error bar increases ==find variations in the bill ,eg friday leghth is high so it is inconsistent 
sns.barplot(x='total_bill',y='day',data=df)#ci=None
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
#ci=none ,to cut error bar ,not prefered

# %%
#6)BOX PLOT (interview)
#used to find(detect) outlayers(wrong data)
#Q1 =25 th percentile(lower bound)
#Q2 =median 50 percentile
#Q3-75 th percentile
#whiskers=line extending from the box
#upper whisker = maximum value 
#lower whisker = minimum value
#Box is called IQR INTER Quartile range
sns.boxplot(x='smoker',y='total_bill',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
df['total_bill'].unique()
# Out:
# array([16.99, 10.34, 21.01, 23.68, 24.59, 25.29,  8.77, 26.88, 15.04,
#        14.78, 10.27, 35.26, 15.42, 18.43, 14.83, 21.58, 10.33, 16.29,
#        16.97, 20.65, 17.92, 20.29, 15.77, 39.42, 19.82, 17.81, 13.37,
#        12.69, 21.7 , 19.65,  9.55, 18.35, 15.06, 20.69, 17.78, 24.06,
#        16.31, 16.93, 18.69, 31.27, 16.04, 17.46, 13.94,  9.68, 30.4 ,
#        18.29, 22.23, 32.4 , 28.55, 18.04, 12.54, 10.29, 34.81,  9.94,
#        25.56, 19.49, 38.01, 26.41, 11.24, 48.27, 13.81, 11.02, 17.59,
#        20.08, 16.45,  3.07, 20.23, 15.01, 12.02, 17.07, 26.86, 25.28,
#        14.73, 10.51, 27.2 , 22.76, 17.29, 19.44, 16.66, 10.07, 32.68,
#        15.98, 34.83, 13.03, 18.28, 24.71, 21.16, 28.97, 22.49,  5.75,
#        16.32, 22.75, 40.17, 27.28, 12.03, 12.46, 11.35, 15.38, 44.3 ,
#        22.42, 20.92, 15.36, 20.49, 25.21, 18.24, 14.31, 14.  ,  7.25,
#        38.07, 23.95, 25.71, 17.31, 29.93, 10.65, 12.43, 24.08, 11.69,
# ...

# %%
sns.boxplot(y='total_bill',data=df)
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(y='tip',data=df)
# Out:
# <Axes: ylabel='tip'>

# %%
sns.boxplot(y='size',data=df)
# Out:
# <Axes: ylabel='size'>

# %%
sns.boxplot(x='time',y='total_bill',data=df,hue='sex')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='tip',data=df,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
import matplotlib.pyplot as plt
def removal_box_plot(df,column,threshold):
    sns.boxplot(df[column])
    plt.title(f"Original box plot of {column}")
    plt.show()

    removed_outliers=df[df[column]<=threshold]

    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers

threshold_value=40
no_outliers=removal_box_plot(df,'total_bill',threshold_value)

# %%
import numpy as np
Q1=np.percentile(df['total_bill'],25,method='midpoint')
Q3=np.percentile(df['total_bill'],75,method='midpoint')
IQR=Q3-Q1
print(IQR)

upper=Q3+1.5*IQR
upper_array=np.array(df['total_bill']>=upper)
print('upper bound',upper)
print(upper_array.sum())

#below lower bound
lower=Q1-1.5*IQR
lower_array=np.array(df['total_bill'])<=lower
print('lower bound',lower)
print(lower_array.sum())
# Out:
# 10.849999999999998
# upper bound 40.449999999999996
# 9
# lower bound -2.9499999999999993
# 0

# %% [markdown]
# Outlayers removal methods in box plot
#
# 1.manual method
# 2.Capping or Winsorizing
# Instead of removing outliers, you can cap them at the lower and upper bounds.
# 3. Transformations
# Applying a transformation (like logarithmic, square root, or Box-Cox transformation) can reduce the influence of outliers.
# 4.Use Robust Statistical Methods
# Instead of removing or transforming the data, use models that are less sensitive to outliers, such as:
# Robust regression models (like Huber or RANSAC in machine learning)
# Median instead of mean when aggregating data
# 5. Imputation
# Replace outliers with the mean or median of the data.

# %% [markdown]
# Chi-Square (χ²) Test
# *To find relationship between two categorical columns
# *The Chi-Square test evaluates if two categorical variables are independent.
# *Seaborn helps visualize relationships, but the actual test is done using scipy.stats.chi2_contingency.
# *If the p-value is small (e.g., < 0.05), you reject the null hypothesis and conclude that there is a significant relationship between the two variables.
