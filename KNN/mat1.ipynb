# %%
import matplotlib.pyplot as plt
x=[34,56,376,678]
y=[345,87,678,987]
plt.plot(x,y)

# %%
#array
import numpy as np
x=np.array([12,22,23,43])
y=np.array([12,23,43,22])
plt.plot(x,y)

# %%
z=np.array([1,2,3,4])
plt.plot(z)

# %%
x=[34,56,376,678]
y=[345,87,678,987]
plt.plot(x,y,'s')

# %%
x=[34,56,376,678]
y=[345,87,678,987]
plt.plot(x,y,marker='+')

# %%
x=[34,56,376,678]
y=[345,87,678,987]
plt.plot(x,y,'s:r')

# %%
x=[34,56,376,678]
y=[345,87,678,987]
plt.plot(x,y,'*-g')

# %%
x=[34,56,376,678]
y=[345,87,678,987]
plt.plot(x,y,'*:g')
