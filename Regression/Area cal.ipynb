# %%
import matplotlib.pyplot as plt

# %%
Area=[2600,2800,3100,3400,3800]
price=[5600000,5800000,6100000,6600000,7200000]
plt.scatter(Area,price,color='r')
plt.xlabel('Area',color='g')
plt.ylabel('Price',color='g')
plt.title('Area-Price Graph',color='c',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Area-Price Graph')
